# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
import requests

# %%
html_content = requests.get("https://stats.espncricinfo.com/ci/engine/records/team/match_results_year.html?class=2;id=202;type=decade")
soup = BeautifulSoup(html_content.content,"html.parser")
anchor = soup.find_all("a",class_ = "QuoteSummary")
yearwise_links = ["https://stats.espncricinfo.com" + a['href'] for a in anchor]
print(yearwise_links)
# Out:
# ['https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2020;type=year', 'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2021;type=year', 'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2022;type=year', 'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2023;type=year']

# %% [markdown]
# # Scrap the matches between 2020-current

# %%
def scrap_matches_info(links_list):
    df = pd.DataFrame()
    match_links = []
    for link in links_list:
        html_text = requests.get(link)
        soup = BeautifulSoup(html_text.content,"html.parser")
        table = soup.find("table",class_ = "engineTable")
        columns = []
        for th in table.find('thead').find_all('th'):
            columns.append(th.text.strip())
        data = []
        for tr in table.find('tbody').find_all('tr'):
            row = []
            for td in tr.find_all('td'):
                row.append(td.text.strip())
                if td.find('a'):
                    link = td.find('a')['href']
                    if 'match' in link:
                        match_links.append("https://stats.espncricinfo.com" + link)
            if row[2] == 'no result': 
                if match_links:
                    match_links.pop() 
                continue 
            data.append(row)
        columns = ['Team 1','Team 2','Winner','Margin','Ground','Match Date','Match id']   
        for row in data:
            match = row[0] + " vs " + row[1]
            row.insert(0, match)
            df = df.append(pd.Series(row, index=['Match'] + columns), ignore_index=True)
    return df, match_links

# %%
matches_df,match_links = scrap_matches_info(yearwise_links)

# %%
matches_df.to_csv("matches_info.csv",index=False)

# %%
match_links[-1]
# Out:
# 'https://stats.espncricinfo.com/ci/engine/match/1358081.html'

# %% [markdown]
# # Now scrap each matches players performance

# %%
def scrap_stats_of_matches(match_url):
    batting_df = pd.DataFrame()
    bowling_df = pd.DataFrame()
    
    html_content = requests.get(match_url)
    soup = BeautifulSoup(html_content.content,"html.parser")
    try:
        batting_and_bowling = soup.find_all("div",class_ = "ds-p-0")[1:3]
        match_number_div = soup.find_all("div",class_ = "ds-p-0")[3]
        match_number = match_number_div.find_all("span",class_ = "ds-text-tight-s ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block")[-1].text.split(" ")[-1]
    #     print(match_number)
        innings_batting_data = []
        innings_bowling_data = []
        inningsTeam = soup.find_all("span",class_ = "ds-text-title-xs ds-font-bold ds-capitalize")
        team1 = inningsTeam[0].text
        team2 = inningsTeam[1].text
        match_name = team1 + " Vs"  + team2
        print(f"Processing match: {match_name} with match id: {match_number}")
        for div in batting_and_bowling:
            innings_team_name = inningsTeam.pop(0).text
            table = div.find_all("table")
            innings_batting = table[0]
            batting_columns = []
            for th in innings_batting.find("thead").find_all('th'):
                batting_columns.append(th.text.strip())
            batting_data = []
            for tr in innings_batting.find("tbody").find_all('tr'):
                batting_row = []
                for td in tr.find_all("td"):
                    batting_row.append(td.text.strip())
                if any(batting_row):
                    batting_data.append(batting_row) 
            batting_columns = ['Batsman Name','Dismissal','Runs','Balls','M','4s','6s','Strike Rate']
            innings_batting_df = pd.DataFrame(batting_data, columns=batting_columns)
            innings_batting_df = innings_batting_df[~innings_batting_df['Batsman Name'].str.contains('Extras|TOTAL|Did not bat|Fall of wickets')]
            innings_batting_df.insert(0, "teamInnings", innings_team_name)
            innings_batting_df.insert(1, "Batting Position", range(1, 1+len(innings_batting_df)))
            innings_batting_df.insert(10,"Match id",match_number)
            batting_df = batting_df.append(innings_batting_df, ignore_index=True)

            #bowling scorecard
            innings_bowling = table[1]
            bowling_columns = []
            for th in innings_bowling.find("thead").find_all('th'):
                bowling_columns.append(th.text.strip())
            bowling_data = []
            for tr in innings_bowling.find("tbody").find_all('tr'):
                bowling_row = []
                for td in tr.find_all("td"):
                    bowling_row.append(td.text.strip())
                if len(bowling_row)!=1:
                    bowling_data.append(bowling_row) 
            bowling_columns = ['Bowler Name','Over','Maiden','Runs','Wickets','Economy','dots','fours','sixes','wides','no balls']
            innings_bowling_df = pd.DataFrame(bowling_data, columns=bowling_columns)
            if innings_team_name == team1:
                innings_team_name = team2
            else:
                innings_team_name = team1
            innings_bowling_df.insert(0, "match", match_name)
            innings_bowling_df.insert(1, "teamInnings", innings_team_name)
            innings_bowling_df.insert(13,"Match Id",match_number)
            bowling_df = bowling_df.append(innings_bowling_df, ignore_index=True)
    except:
        pass
        
    return batting_df,bowling_df

# %%
#saving odi matches scorecard
combined_batting_df = pd.DataFrame()
combined_bowling_df = pd.DataFrame()

# Loop through the match URLs
for match_url in match_links:
    batting_df, bowling_df = scrap_stats_of_matches(match_url)
    combined_batting_df = combined_batting_df.append(batting_df)
    combined_bowling_df = combined_bowling_df.append(bowling_df)

# Write the combined batting and bowling dataframes to CSV files
combined_batting_df.to_csv('batting_data.csv', index=False)
combined_bowling_df.to_csv('bowling_data.csv', index=False)
# Out:
# Processing match: United Arab Emirates VsOman with match id: 4224
# Processing match: United Arab Emirates VsNamibia with match id: 4225
# Processing match: Ireland VsWest Indies with match id: 4226
# Processing match: Namibia VsOman with match id: 4227
# Processing match: Namibia VsUnited Arab Emirates with match id: 4228
# Processing match: Ireland VsWest Indies with match id: 4229
# Processing match: Ireland VsWest Indies with match id: 4230
# Processing match: India VsAustralia with match id: 4231
# Processing match: India VsAustralia with match id: 4232
# Processing match: Australia VsIndia with match id: 4233
# Processing match: England VsSouth Africa with match id: 4234
# Processing match: India VsNew Zealand with match id: 4235
# Processing match: Oman VsNepal with match id: 4236
# Processing match: United States of America VsOman with match id: 4237
# Processing match: New Zealand VsIndia with match id: 4239
# Processing match: Nepal VsUnited States of America with match id: 4240
# Processing match: Nepal VsOman with match id: 4241
# Processing match: South Africa VsEngland with match id: 4242
# Processing match: India VsNew Zealand with match id: 4243
# Processing match: Oman VsUnited States of America with match id: 4244
# Processing match: United States of America VsNepal with match id: 4245
# Processing match: West Indies VsSri Lanka with match id: 4246
# Processing match: Sri Lanka VsWest Indies with match id: 4247
# Processing match: South Africa VsAustralia with match id: 4248
# Processing match: Bangladesh VsZimbabwe with match id: 4249
# Processing match: Sri Lanka VsWest Indies with match id: 4250
# Processing match: Bangladesh VsZimbabwe with match id: 4251
# Processing match: Australia VsSouth Africa with match id: 4252
# Processing match: Bangladesh VsZimbabwe with match id: 4253
# Processing match: Australia VsSouth Africa with match id: 4254
# Processing match: Australia VsNew Zealand with match id: 4255
# Processing match: Ireland VsEngland with match id: 4256
# Processing match: Ireland VsEngland with match id: 4257
# Processing match: England VsIreland with match id: 4258
# Processing match: Australia VsEngland with match id: 4259
# Processing match: England VsAustralia with match id: 4260
# Processing match: England VsAustralia with match id: 4261
# Processing match: Pakistan VsZimbabwe with match id: 4262
# Processing match: Zimbabwe VsPakistan with match id: 4263
# Processing match: Zimbabwe VsPakistan with match id: 4264
# Processing match: Australia VsIndia with match id: 4265
# Processing match: Australia VsIndia with match id: 4266
# Processing match: India VsAustralia with match id: 4267
# Processing match: Ireland VsUnited Arab Emirates with match id: 4268
# Processing match: Ireland VsUnited Arab Emirates with match id: 4269
# Processing match: West Indies VsBangladesh with match id: 4270
# Processing match: Afghanistan VsIreland with match id: 4271
# Processing match: West Indies VsBangladesh with match id: 4272
# Processing match: Ireland VsAfghanistan with match id: 4273
# Processing match: Bangladesh VsWest Indies with match id: 4274
# Processing match: Afghanistan VsIreland with match id: 4275
# Processing match: Sri Lanka VsWest Indies with match id: 4276
# Processing match: Sri Lanka VsWest Indies with match id: 4277
# Processing match: Sri Lanka VsWest Indies with match id: 4278
# Processing match: Bangladesh VsNew Zealand with match id: 4279
# Processing match: Bangladesh VsNew Zealand with match id: 4280
# Processing match: India VsEngland with match id: 4281
# Processing match: New Zealand VsBangladesh with match id: 4282
# Processing match: India VsEngland with match id: 4283
# Processing match: India VsEngland with match id: 4284
# Processing match: South Africa VsPakistan with match id: 4285
# Processing match: South Africa VsPakistan with match id: 4286
# Processing match: Pakistan VsSouth Africa with match id: 4287
# Processing match: Netherlands VsScotland with match id: 4288
# Processing match: Netherlands VsScotland with match id: 4289
# Processing match: Bangladesh VsSri Lanka with match id: 4290
# Processing match: Bangladesh VsSri Lanka with match id: 4291
# Processing match: Sri Lanka VsBangladesh with match id: 4292
# Processing match: Netherlands VsIreland with match id: 4293
# Processing match: Netherlands VsIreland with match id: 4294
# Processing match: Ireland VsNetherlands with match id: 4295
# Processing match: Sri Lanka VsEngland with match id: 4296
# Processing match: Sri Lanka VsEngland with match id: 4297
# Processing match: Pakistan VsEngland with match id: 4299
# Processing match: England VsPakistan with match id: 4300
# Processing match: Ireland VsSouth Africa with match id: 4302
# Processing match: Pakistan VsEngland with match id: 4303
# Processing match: Bangladesh VsZimbabwe with match id: 4304
# Processing match: South Africa VsIreland with match id: 4305
# Processing match: Zimbabwe VsBangladesh with match id: 4306
# Processing match: Sri Lanka VsIndia with match id: 4307
# Processing match: Zimbabwe VsBangladesh with match id: 4308
# Processing match: Sri Lanka VsIndia with match id: 4309
# Processing match: Australia VsWest Indies with match id: 4310
# Processing match: Australia VsWest Indies with match id: 4311
# Processing match: India VsSri Lanka with match id: 4312
# Processing match: West Indies VsAustralia with match id: 4313
# Processing match: Sri Lanka VsSouth Africa with match id: 4314
# Processing match: South Africa VsSri Lanka with match id: 4315
# Processing match: Papua New Guinea VsUnited States of America with match id: 4316
# Processing match: Papua New Guinea VsNepal with match id: 4317
# Processing match: Sri Lanka VsSouth Africa with match id: 4318
# Processing match: Zimbabwe VsIreland with match id: 4319
# Processing match: United States of America VsPapua New Guinea with match id: 4320
# Processing match: Nepal VsPapua New Guinea with match id: 4322
# Processing match: Zimbabwe VsIreland with match id: 4323
# Processing match: United States of America VsNepal with match id: 4324
# Processing match: Nepal VsOman with match id: 4325
# Processing match: United States of America VsOman with match id: 4326
# Processing match: Nepal VsUnited States of America with match id: 4327
# Processing match: Oman VsNepal with match id: 4328
# Processing match: Oman VsUnited States of America with match id: 4329
# Processing match: Papua New Guinea VsScotland with match id: 4330
# Processing match: Oman VsPapua New Guinea with match id: 4331
# Processing match: Scotland VsOman with match id: 4332
# Processing match: Papua New Guinea VsScotland with match id: 4333
# Processing match: Papua New Guinea VsOman with match id: 4334
# Processing match: Namibia VsOman with match id: 4336
# Processing match: Oman VsNamibia with match id: 4338
# Processing match: West Indies VsIreland with match id: 4339
# Processing match: West Indies VsIreland with match id: 4340
# Processing match: Zimbabwe VsSri Lanka with match id: 4341
# Processing match: West Indies VsIreland with match id: 4342
# Processing match: Zimbabwe VsSri Lanka with match id: 4343
# Processing match: South Africa VsIndia with match id: 4344
# Processing match: Afghanistan VsNetherlands with match id: 4345
# Processing match: India VsSouth Africa with match id: 4346
# Processing match: Sri Lanka VsZimbabwe with match id: 4347
# Processing match: Afghanistan VsNetherlands with match id: 4348
# Processing match: South Africa VsIndia with match id: 4349
# Processing match: Afghanistan VsNetherlands with match id: 4350
# Processing match: Oman VsUnited Arab Emirates with match id: 4351
# Processing match: Oman VsUnited Arab Emirates with match id: 4352
# Processing match: West Indies VsIndia with match id: 4353
# Processing match: Oman VsUnited Arab Emirates with match id: 4354
# Processing match: India VsWest Indies with match id: 4355
# Processing match: India VsWest Indies with match id: 4356
# Processing match: Afghanistan VsBangladesh with match id: 4357
# Processing match: Bangladesh VsAfghanistan with match id: 4358
# Processing match: Bangladesh VsAfghanistan with match id: 4359
# Processing match: Oman VsUnited Arab Emirates with match id: 4360
# Processing match: Namibia VsOman with match id: 4361
# Processing match: Namibia VsUnited Arab Emirates with match id: 4362
# Processing match: Oman VsUnited Arab Emirates with match id: 4363
# Processing match: Namibia VsOman with match id: 4364
# Processing match: United Arab Emirates VsNamibia with match id: 4365
# Processing match: Oman VsNamibia with match id: 4366
# Processing match: Papua New Guinea VsUnited Arab Emirates with match id: 4367
# Processing match: Papua New Guinea VsNepal with match id: 4368
# Processing match: United Arab Emirates VsNepal with match id: 4369
# Processing match: Bangladesh VsSouth Africa with match id: 4370
# Processing match: United Arab Emirates VsPapua New Guinea with match id: 4371
# Processing match: Bangladesh VsSouth Africa with match id: 4372
# Processing match: United Arab Emirates VsNepal with match id: 4373
# Processing match: Papua New Guinea VsNepal with match id: 4374
# Processing match: South Africa VsBangladesh with match id: 4375
# Processing match: Papua New Guinea VsNepal with match id: 4376
# Processing match: Nepal VsPapua New Guinea with match id: 4377
# Processing match: Netherlands VsNew Zealand with match id: 4378
# Processing match: Australia VsPakistan with match id: 4379
# Processing match: Australia VsPakistan with match id: 4380
# Processing match: New Zealand VsNetherlands with match id: 4381
# Processing match: Australia VsPakistan with match id: 4382
# Processing match: New Zealand VsNetherlands with match id: 4383
# Processing match: Scotland VsPapua New Guinea with match id: 4384
# Processing match: Scotland VsOman with match id: 4385
# Processing match: Papua New Guinea VsOman with match id: 4386
# Processing match: Scotland VsPapua New Guinea with match id: 4387
# Processing match: Oman VsScotland with match id: 4388
# Processing match: Oman VsPapua New Guinea with match id: 4389
# Processing match: United States of America VsScotland with match id: 4390
# Processing match: Scotland VsUnited States of America with match id: 4391
# Processing match: Netherlands VsWest Indies with match id: 4392
# Processing match: United Arab Emirates VsScotland with match id: 4393
# Processing match: United Arab Emirates VsUnited States of America with match id: 4394
# Processing match: Netherlands VsWest Indies with match id: 4395
# Processing match: Scotland VsUnited Arab Emirates with match id: 4396
# Processing match: Afghanistan VsZimbabwe with match id: 4397
# Processing match: West Indies VsNetherlands with match id: 4398
# Processing match: United States of America VsUnited Arab Emirates with match id: 4399
# Processing match: Zimbabwe VsAfghanistan with match id: 4400
# Processing match: West Indies VsPakistan with match id: 4401
# Processing match: United States of America VsOman with match id: 4402
# Processing match: Zimbabwe VsAfghanistan with match id: 4403
# Processing match: Oman VsNepal with match id: 4404
# Processing match: Pakistan VsWest Indies with match id: 4405
# Processing match: Nepal VsUnited States of America with match id: 4406
# Processing match: Pakistan VsWest Indies with match id: 4407
# Processing match: Oman VsUnited States of America with match id: 4408
# Processing match: Sri Lanka VsAustralia with match id: 4409
# Processing match: Oman VsNepal with match id: 4410
# Processing match: United States of America VsNepal with match id: 4411
# Processing match: Sri Lanka VsAustralia with match id: 4412
# Processing match: England VsNetherlands with match id: 4413
# Processing match: Netherlands VsEngland with match id: 4414
# Processing match: Australia VsSri Lanka with match id: 4415
# Processing match: Sri Lanka VsAustralia with match id: 4416
# Processing match: Netherlands VsEngland with match id: 4417
# Processing match: Sri Lanka VsAustralia with match id: 4418
# Processing match: Ireland VsNew Zealand with match id: 4419
# Processing match: Scotland VsNamibia with match id: 4420
# Processing match: West Indies VsBangladesh with match id: 4421
# Processing match: Namibia VsNepal with match id: 4422
# Processing match: Ireland VsNew Zealand with match id: 4423
# Processing match: England VsIndia with match id: 4424
# Processing match: Scotland VsNepal with match id: 4425
# Processing match: West Indies VsBangladesh with match id: 4426
# Processing match: Namibia VsScotland with match id: 4427
# Processing match: England VsIndia with match id: 4428
# Processing match: New Zealand VsIreland with match id: 4429
# Processing match: Namibia VsNepal with match id: 4430
# Processing match: West Indies VsBangladesh with match id: 4431
# Processing match: Nepal VsScotland with match id: 4432
# Processing match: England VsIndia with match id: 4433
# Processing match: South Africa VsEngland with match id: 4434
# Processing match: England VsSouth Africa with match id: 4435
# Processing match: India VsWest Indies with match id: 4436
# Processing match: West Indies VsIndia with match id: 4438
# Processing match: India VsWest Indies with match id: 4439
# Processing match: Scotland VsNew Zealand with match id: 4440
# Processing match: Bangladesh VsZimbabwe with match id: 4441
# Processing match: Bangladesh VsZimbabwe with match id: 4442
# Processing match: Bangladesh VsZimbabwe with match id: 4443
# Processing match: Scotland VsUnited Arab Emirates with match id: 4444
# Processing match: United Arab Emirates VsUnited States of America with match id: 4445
# Processing match: United States of America VsScotland with match id: 4446
# Processing match: Scotland VsUnited Arab Emirates with match id: 4447
# Processing match: Pakistan VsNetherlands with match id: 4448
# Processing match: Scotland VsUnited States of America with match id: 4449
# Processing match: New Zealand VsWest Indies with match id: 4450
# Processing match: Zimbabwe VsIndia with match id: 4451
# Processing match: Netherlands VsPakistan with match id: 4452
# Processing match: New Zealand VsWest Indies with match id: 4453
# Processing match: Zimbabwe VsIndia with match id: 4454
# Processing match: Pakistan VsNetherlands with match id: 4455
# Processing match: West Indies VsNew Zealand with match id: 4456
# Processing match: India VsZimbabwe with match id: 4457
# Processing match: Zimbabwe VsAustralia with match id: 4458
# Processing match: Zimbabwe VsAustralia with match id: 4459
# Processing match: Australia VsZimbabwe with match id: 4460
# Processing match: New Zealand VsAustralia with match id: 4461
# Processing match: Australia VsNew Zealand with match id: 4462
# Processing match: United States of America VsPapua New Guinea with match id: 4463
# Processing match: Australia VsNew Zealand with match id: 4464
# Processing match: Papua New Guinea VsUnited States of America with match id: 4465
# Processing match: Namibia VsUnited States of America with match id: 4466
# Processing match: Namibia VsUnited States of America with match id: 4467
# Processing match: Namibia VsPapua New Guinea with match id: 4468
# Processing match: Namibia VsPapua New Guinea with match id: 4469
# Processing match: South Africa VsIndia with match id: 4470
# Processing match: South Africa VsIndia with match id: 4471
# Processing match: South Africa VsIndia with match id: 4472
# Processing match: United Arab Emirates VsNepal with match id: 4473
# Processing match: United Arab Emirates VsNepal with match id: 4474
# Processing match: England VsAustralia with match id: 4475
# Processing match: United Arab Emirates VsNepal with match id: 4476
# Processing match: Australia VsEngland with match id: 4477
# Processing match: Papua New Guinea VsNamibia with match id: 4478
# Processing match: United States of America VsNamibia with match id: 4479
# Processing match: Australia VsEngland with match id: 4480
# Processing match: Papua New Guinea VsUnited States of America with match id: 4481
# Processing match: Papua New Guinea VsNamibia with match id: 4482
# Processing match: India VsNew Zealand with match id: 4483
# Processing match: United States of America VsPapua New Guinea with match id: 4484
# Processing match: Afghanistan VsSri Lanka with match id: 4485
# Processing match: United States of America VsNamibia with match id: 4486
# Processing match: Afghanistan VsSri Lanka with match id: 4490
# Processing match: Namibia VsScotland with match id: 4491
# Processing match: India VsBangladesh with match id: 4493
# Processing match: Nepal VsScotland with match id: 4494
# Processing match: Scotland VsNamibia with match id: 4495
# Processing match: Bangladesh VsIndia with match id: 4496
# Processing match: Namibia VsNepal with match id: 4497
# Processing match: Nepal VsScotland with match id: 4498
# Processing match: India VsBangladesh with match id: 4499
# Processing match: New Zealand VsPakistan with match id: 4500
# Processing match: India VsSri Lanka with match id: 4501
# Processing match: New Zealand VsPakistan with match id: 4502
# Processing match: Sri Lanka VsIndia with match id: 4503
# Processing match: Pakistan VsNew Zealand with match id: 4504
# Processing match: India VsSri Lanka with match id: 4505
# Processing match: Ireland VsZimbabwe with match id: 4506
# Processing match: India VsNew Zealand with match id: 4507
# Processing match: Ireland VsZimbabwe with match id: 4508
# Processing match: New Zealand VsIndia with match id: 4509
# Processing match: India VsNew Zealand with match id: 4511
# Processing match: South Africa VsEngland with match id: 4512
# Processing match: England VsSouth Africa with match id: 4513
# Processing match: England VsSouth Africa with match id: 4514
# Processing match: Namibia VsNepal with match id: 4515
# Processing match: Namibia VsScotland with match id: 4516
# Processing match: Scotland VsNepal with match id: 4517
# Processing match: Namibia VsNepal with match id: 4518
# Processing match: Scotland VsNamibia with match id: 4519
# Processing match: Scotland VsNepal with match id: 4520
# Processing match: Namibia VsUnited Arab Emirates with match id: 4521
# Processing match: United Arab Emirates VsNamibia with match id: 4522
